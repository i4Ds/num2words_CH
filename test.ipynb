# %%
from num2words.detect_convert_ch_numbers import convert_numbers

# %%
convert_numbers("Am 20.12.2024 treffen wir uns.",dialect="ch_bs")
# Out:
# 'Am zwanzig.zwölf.zweitusigvieräzwanzig treffen wir uns.'

# %%
convert_numbers("Der 20. Ball traf das Ziel.",dialect="ch_sg")
# Out:
# Jan 06, 2026 2:38:04 PM de.unihd.dbs.heideltime.standalone.HeidelTimeStandalone process
# INFO: Processing started
# Jan 06, 2026 2:38:04 PM de.unihd.dbs.heideltime.standalone.HeidelTimeStandalone process
# INFO: Processing finished
# Jan 06, 2026 2:38:04 PM de.unihd.dbs.heideltime.standalone.HeidelTimeStandalone process
# INFO: Result formatted
# 'Der zwanzgsti Ball traf das Ziel.'
